# %% [markdown]
# ### Word Document Processing

# %%
from docx import Document as DocxDocument
import os
from langchain_community.document_loaders import Docx2txtLoader, UnstructuredWordDocumentLoader

# %%
### METHOD 1 : Using DocxtxtLoader
print("1️⃣ Using Docx2txtLoader")
try:
    docx_loader=Docx2txtLoader("data/doc_word/DevOps_Upskilling_Plan_Ayman.docx")
    docs=docx_loader.load()
    print(f"✅ Loaded {len(docs)} document(s)")
    print(f"Content preview: {docs[0].page_content[:200]}...")
    print(f"Metadata: {docs[0].metadata}")

except Exception as e:
    print(f"Error: {e}")
# Out:
# 1️⃣ Using Docx2txtLoader
# ✅ Loaded 1 document(s)
# Content preview: 🧭 DevOps Upskilling Plan
#
# This comprehensive roadmap is designed to help you transition from a Java developer into a skilled DevOps engineer over 6 months. It aligns with your full-time schedule by re...
# Metadata: {'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx'}

# %%
## Method2 : Using UnstructuredWordDocumentLoader
print("\n2️⃣ Using UnstructuredWordDocumentLoader")

try:
    unstructured_loader=UnstructuredWordDocumentLoader("data/doc_word/DevOps_Upskilling_Plan_Ayman.docx", mode="elements")
    unstructured_docs=unstructured_loader.load()

    print(f"✅ Loaded {len(unstructured_docs)} elements")
    for i, doc in enumerate(unstructured_docs[:3]):
        print(f"\nElement {i+1}:")
        print(f"Type: {doc.metadata.get('category', 'unknown')}")
        print(f"Content: {doc.page_content[:100]}...")

except Exception as e:
    print(e)
# Out:
# 2️⃣ Using UnstructuredWordDocumentLoader
# ✅ Loaded 109 elements
#
# Element 1:
# Type: UncategorizedText
# Content: 🧭 DevOps Upskilling Plan...
#
# Element 2:
# Type: NarrativeText
# Content: This comprehensive roadmap is designed to help you transition from a Java developer into a skilled D...
#
# Element 3:
# Type: ListItem
# Content: Weekdays (Mon–Fri): 1.5 h/day (post-work evenings)...

# %%
unstructured_docs
# Out:
# [Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['🧭', 'DevOps Upskilling Plan'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '601609ac2b4ae7e7e15b4d0e0ff1555f'}, page_content='🧭 DevOps Upskilling Plan'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '7085b6fea526909f76688e57966ecb54'}, page_content='This comprehensive roadmap is designed to help you transition from a Java developer into a skilled DevOps engineer over 6 months. It aligns with your full-time schedule by recommending a flexible weekly study commitment of 13.5 hours:'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Weekdays (Mon–Fri):'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a783c60f3608dc9739e0f0e5ba291996'}, page_content='Weekdays (Mon–Fri): 1.5 h/day (post-work evenings)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Weekends (Sat & Sun):'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '937675cc835979d8415efd04cc1e33af'}, page_content='Weekends (Sat & Sun): 3 h/day (morning or afternoon sessions)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['⏱', 'Total Duration: ~36 Weeks'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '48f9dc5fd2e64be9b2baa5b4f475a3eb'}, page_content='⏱ Total Duration: ~36 Weeks'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Video Lectures:', 'Hands-On Practice:', 'Output:'], 'emphasized_text_tags': ['b', 'b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '34c0b44da1582209c3da86416b1a0493'}, page_content='📺 Video Lectures: ~168 hours\n🧪 Hands-On Practice: ~168 hours\n💼 Output: A complete DevOps portfolio hosted in a Git repository (GitHub/GitLab)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 1: Foundations (Linux, Networking & Scripting)'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '079a3c945b5f2d6e348eba0ce0032636'}, page_content='📌 Phase 1: Foundations (Linux, Networking & Scripting)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '51b648cdfd12e6b2fc8f7e7b98cbf1ac'}, page_content='Duration: 4 weeks (24h video + 24h practice)\nGoal: Build a solid foundation in Linux, networking, and automation scripting.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['1.1 Linux & Networking'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '73d68ed084dc5111671933bf088f81a6'}, page_content='1.1 Linux & Networking'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '41007ef433f11549e952895ca4ec65a2'}, page_content='Course: Linux Mastery: Master the Linux Command Line in 11.5 Hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a5a15c7cb9e4e8e40b0767cc6603a6dc'}, page_content='Content: 11.5 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'link_texts': ['linuxjourney.com'], 'link_urls': ['https://linuxjourney.com'], 'links': [{'text': 'linuxjourney.com', 'url': 'https://linuxjourney.com', 'start_index': 54}], 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '3c874b770663047a786f8b0b15e15125'}, page_content='Hands-On: Practice weekly with a local VM or WSL. Use linuxjourney.com & OverTheWire Bandit (Levels 1–5).'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['1.2 Bash Scripting'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'ffbb18ccab8e3a25bb077ca2857007e7'}, page_content='1.2 Bash Scripting'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'c37409306ae15aa5bc0a495100c8ac70'}, page_content='Course: Bash Scripting and Shell Programming'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'd4d03884c91c947fb9e0df11df483c57'}, page_content='Content: 2.5 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '828c80d5db9d87bfdaa5bddbf9ba29f3'}, page_content='Hands-On: Write backup scripts, cron jobs, log processors, and health check scripts.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['1.3 Python for Automation'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '2c1e9069201d603ab80194664c300e00'}, page_content='1.3 Python for Automation'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '4f58ef5a3c43ca02730cd4fbc14b5a84'}, page_content='Course: Automate the Boring Stuff with Python'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '972e8f306642c102d9214d45e5ae6c38'}, page_content='Content: 9.5 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'languages': ['eng'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'PageBreak', 'element_id': '977ee4c3449e9893db8be38839a8b011'}, page_content=''),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '0a937834125e939c3f0888151c212627'}, page_content='Hands-On: Write weekly scripts for REST APIs, log parsing, or file operations. Push to Git.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase', '2: Version Control & CI/CD'], 'emphasized_text_tags': ['b', 'b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'e435b560594fdd31ba1b68b315f55913'}, page_content='📌 Phase 2: Version Control & CI/CD'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '1fd00d72699aa7c8ff99ba65b693286d'}, page_content='Duration: 3 weeks (11h video + 11h practice)\nGoal: Learn Git workflows and build a simple CI pipeline with Jenkins.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['2.1 Git Mastery'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'e317c4fb3447911ec3066f3fc3f48159'}, page_content='2.1 Git Mastery'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '90231cc59efbf5f5779ae91dec1629a5'}, page_content='Course: Git Complete: The Definitive Guide'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'c0632c578dd99087d79d066a8302da09'}, page_content='Content: 6.1 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'd36aa64b93e491a708a006907140bfd5'}, page_content='Hands-On: Simulate team workflows with feature branches, PRs, and merges.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['2.2 Jenkins CI/CD'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'dd9341ca107b3b779f3a9b3043674a18'}, page_content='2.2 Jenkins CI/CD'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'cd27ad807ffda5825dff6a2d03b5cd3d'}, page_content='Course: CI/CD with Jenkins & Docker'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '6e7d6237264a87fc827e1d72df8b34d5'}, page_content='Content: 4.9 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'de971bd8477322bc3ccb463b4366ba0a'}, page_content='Hands-On: Create a Jenkins pipeline for a Java app. Integrate Maven/Gradle, tests, and Docker builds.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 3: Containers & Kubernetes'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'ddcb0632cb4c517271154098a84b9f56'}, page_content='📌 Phase 3: Containers & Kubernetes'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': 'ebd5b4e4b3db512ad7b7a12a4576d5c8'}, page_content='Duration: 8 weeks (37h video + 37h practice)\nGoal: Containerize your app and deploy it on Kubernetes.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['3.1 Docker Fundamentals'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '2fb8c77070c55af43b9c55de52c73762'}, page_content='3.1 Docker Fundamentals'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '237ce605ac643e1928bef9cfb14837d5'}, page_content='Course: Docker Mastery'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'b0c7312e442f0abc8fd08afdc446bf1d'}, page_content='Content: 7.5 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '63c82bdf0b90dd47485d821ece4f09bb'}, page_content='Hands-On: Build multi-stage Docker images, explore volumes and networks.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['3.2 Kubernetes + CKA Prep'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'f230cc1ff401670c7b3627b64cf13e13'}, page_content='3.2 Kubernetes + CKA Prep'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '274d18002eb011f5a055b7249b4aca63'}, page_content='Course: CKA with Practice Tests'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 2, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '4ea5085d4ebab21b1761a7dff8fb5658'}, page_content='Content: 30.5 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'languages': ['eng'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'PageBreak', 'element_id': 'eac5f7db444e8324c43eb109c45a16b6'}, page_content=''),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'c482e1daa048c9b3f0019f97e5a7b89e'}, page_content='Hands-On: Use Minikube or Kind to deploy Java apps. Write manifests, perform rolling updates, and package with Helm.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 4: Infrastructure as Code'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '23e5dd7f30b8b9a37bf0963a78057894'}, page_content='📌 Phase 4: Infrastructure as Code'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '8bf59a0a7a540ffdd72973e59976a6eb'}, page_content='Duration: 5 weeks (25h video + 25h practice)\nGoal: Use Terraform to provision infrastructure and Ansible to configure servers.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['4.1 Terraform'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '54bf64596716b72d62c24c5e65b1bf95'}, page_content='4.1 Terraform'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'e865404784f133a1b7cb02809e7dd4b5'}, page_content='Course: Terraform Associate 2025 Prep'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a8622788dd3af9c38dbedfc1151d400e'}, page_content='Content: 16.25 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'ce576295591947f438c96039c833978c'}, page_content='Hands-On: Provision AWS VPCs, EC2, and store remote state in S3.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['4.2 Ansible'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '442657017b8183b345b1a94600423e44'}, page_content='4.2 Ansible'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'b8471ac2d068e8662b1ad005fbbb6fea'}, page_content='Course: Ansible for Beginners'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'ad5cf289e1ed88d0f7b30567a9b134d1'}, page_content='Content: 9.75 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a7e3c5885d85d13445e1bfed5305165e'}, page_content='Hands-On: Configure instances, deploy Java apps, manage secrets with Ansible Vault.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 5: Cloud Platforms (Focus on AWS)'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'ea95273e8f2a0a9e5b371d0c08e65133'}, page_content='📌 Phase 5: Cloud Platforms (Focus on AWS)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '7c5567266e16990c00e0c6f02fe0c287'}, page_content='Duration: 7 weeks (33h video + 33h practice)\nGoal: Master AWS and explore serverless with Lambda and container deployments on EKS.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['5.1 AWS Core Services'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '4171351719517cf02f62be954c0dc8cd'}, page_content='5.1 AWS Core Services'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '840ddc47344bda8d21265b603e7fd533'}, page_content='Course: AWS Solutions Architect Associate SAA-C03'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '29a37089f4fa39a57be3c63e1a2c0abf'}, page_content='Content: 29 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'f080bda11be554a76a8951583d59b9e7'}, page_content='Hands-On: Build S3 buckets, EC2, ELB, RDS; deploy Java apps.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['5.2 AWS Lambda'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '7502b3406e61f5a964af35e2aeac1750'}, page_content='5.2 AWS Lambda'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a75b198108c0c3e8bf5753f752fa7606'}, page_content='Course: AWS Lambda & Serverless Framework'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '75a63ecf025f9fdff3cdc97cb14f8ad3'}, page_content='Content: 4.1 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 3, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'c9fd482ee13788c549388af9d610935e'}, page_content='Hands-On: Create REST APIs using Lambda + API Gateway.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'languages': ['eng'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'PageBreak', 'element_id': 'bda19c0c872ad922df28137d73d1d5cf'}, page_content=''),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['5.3 Kubernetes on AWS (EKS)'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '847ac65db0a98ff54e8a5ee6b9b60d75'}, page_content='5.3 Kubernetes on AWS (EKS)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'e37d539fac90cc3de352e023a632d44d'}, page_content='Course: EKS & DevOps'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '951897ca40599d8e217560903b7dcf3a'}, page_content='Content: 5.3 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '91f0537da6b91f69373d3beb92712b06'}, page_content='Hands-On: Deploy Helm charts to EKS with CI/CD integrations.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Optional:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '2c3b2e57df52cfdbb5593383787258e7'}, page_content='Optional:'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Azure:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '24d5afa3a3b6dcd146b325eb71388ac0'}, page_content='Azure: AZ-900 Exam Prep (4.5 h)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['GCP:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'aae1e2a9de1168c0af0f4327788b509d'}, page_content='GCP: GCP for Beginners (7.8 h)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 6: Monitoring & Observability'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '62c55107ccb2cf368f236efd3544af0c'}, page_content='📌 Phase 6: Monitoring & Observability'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '4b2dc86bca224f75c3db27fd0aa761bb'}, page_content='Duration: 2 weeks (8h video + 8h practice)\nGoal: Implement Prometheus, Grafana, ELK stack, and distributed tracing.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'aaa69b617c83cdf12615b5ff3f795c79'}, page_content='Course: Observability with Grafana, Prometheus, Loki & Tempo'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '72cf36591e73e3334b28cf080a9f175a'}, page_content='Content: 8.1 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '59704ede50cbcdb4b8ff46cfe12daa27'}, page_content='Hands-On: Set up dashboards, alerts, EFK stack, and Tempo or Jaeger tracing.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 7: Security & Compliance (', 'DevSecOps', ')'], 'emphasized_text_tags': ['b', 'b', 'b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'ec366235c09b9ea02c99d9bac57f1472'}, page_content='📌 Phase 7: Security & Compliance (DevSecOps)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'f1889667f679ee53664a7a79dcec2b9e'}, page_content='Duration: 2 weeks (5h video + 5h practice)\nGoal: Integrate security scanning, secrets management, and compliance into pipelines.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'ff4f2d9b2d930de44cef24057b81110c'}, page_content='Course: Hands-On DevSecOps'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '3d0f22cb126ea1b62ed5369d1514590b'}, page_content='Content: 4.9 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '9d2881cd8bf6d02f923d971c11fa24e9'}, page_content='Hands-On: Use Trivy, Checkov, tfsec, HashiCorp Vault or AWS Secrets Manager.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 8:', 'GitOps', '& Service Mesh'], 'emphasized_text_tags': ['b', 'b', 'b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '9c44e43e3e34aa3212ecd2808383cbb9'}, page_content='📌 Phase 8: GitOps & Service Mesh'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 4, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '29c9aff86963f4d9a04343e5ebc726bd'}, page_content='Duration: 3 weeks (7h video + 7h practice)\nGoal: Automate k8s deployments via GitOps and secure microservice communication with Istio.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'languages': ['eng'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'PageBreak', 'element_id': '81fd6f514c036330350e8ffe43717396'}, page_content=''),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['8.1 Argo CD'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '334722480e5e6965134b42fcdddf7e2d'}, page_content='8.1 Argo CD'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '26dbaeb8c2409e17664bef0a8fa887d7'}, page_content='Course: ArgoCD Master Course'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '6fefd7a51b08212cf129f1a3df7ea56b'}, page_content='Content: 4.3 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'c91eb334dbb2e64722bd4d98b803251b'}, page_content='Hands-On: Sync deployments from Git to your k8s cluster. Handle drift detection and auto-reverts.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['8.2 Istio'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'e3bd659870424fa08c37ad0c560991b9'}, page_content='8.2 Istio'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '9d6ed4230979c7ddd667595235243f72'}, page_content='Course: Istio for Kubernetes'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '3a04d20960c3496c901028aea88ca347'}, page_content='Content: 3.1 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a1adc1604cdb01ec2467c22ea4610c68'}, page_content='Hands-On: Implement traffic routing and mTLS with the Bookinfo sample.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['📌', 'Phase 9: Culture, Agile & Soft Skills'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '96a787e52f13c654005ab2ae0d8c8a36'}, page_content='📌 Phase 9: Culture, Agile & Soft Skills'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Duration:', 'Goal:'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '6f86896013e262343d456121be70050e'}, page_content='Duration: 4 weeks (18h video + 18h practice)\nGoal: Gain fluency in Agile, write runbooks, post-mortems, and collaborate in DevOps teams.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Course:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '411a3fd27ba0bb20dbee5c998bf8abf2'}, page_content='Course: Advanced Agile Scrum Master Certification'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Content:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'a5514c49bf729c94313856d7604551a1'}, page_content='Content: 18 hours'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['Hands-On:'], 'emphasized_text_tags': ['b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '1fa79968a03f90aa74afa1514c9fd934'}, page_content='Hands-On: Simulate sprints, write deployment runbooks, and document failure analysis.'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['🎯', 'Milestone Goals by Month'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': 'ff83c8776fd15a6b18b6df9225d64c26'}, page_content='🎯 Milestone Goals by Month'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'emphasized_text_contents': ['Month', 'Goal'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'text_as_html': '<table><tr><td>Month</td><td>Goal</td></tr><tr><td>Month 1</td><td>Proficient in Linux, Bash, and Python</td></tr><tr><td>Month 2</td><td>Git and Jenkins CI/CD pipeline ready</td></tr><tr><td>Month 4</td><td>Docker + Kubernetes deployment complete</td></tr><tr><td>Month 6</td><td>Cloud deployment, observability, DevSecOps, GitOps, and Agile documentation complete</td></tr></table>', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Table', 'element_id': '446be192a2071c07b66eb14867618f3e'}, page_content='Month Goal Month 1 Proficient in Linux, Bash, and Python Month 2 Git and Jenkins CI/CD pipeline ready Month 4 Docker + Kubernetes deployment complete Month 6 Cloud deployment, observability, DevSecOps, GitOps, and Agile documentation complete'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['✅', 'Final Deliverables (DevOps Portfolio)'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '2a65bb36ebacef5c410a10dbb66f6c22'}, page_content='✅ Final Deliverables (DevOps Portfolio)'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'NarrativeText', 'element_id': '8062928a85250ed321f39b6bde2538c0'}, page_content='Your GitHub repo should include:'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '88be790ff084d67c34fe7c87d86fae71'}, page_content='✅ Bash/Python scripts'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '23d780e54990c0c07ff170611f046be7'}, page_content='✅ Jenkins CI/CD files'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '7449842e71693473e01c4282f1af0c6d'}, page_content='✅ Dockerfile + Helm Charts + k8s manifests'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '8d6da39d45285075370f8d8d0f335d52'}, page_content='✅ Terraform modules + Ansible playbooks'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '5eaa76e2bdde49fcde79f73411e9c4df'}, page_content='✅ AWS deployment templates'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '6a8b234ddc6746fafbeb8ec83271b509'}, page_content='✅ Observability dashboards and config'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'f7105b7b9e5a5597bee6f264acc0d1db'}, page_content='✅ Vault and security scan integrations'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': 'bfa5ea82f0b1a85c4fccd0abf5f96116'}, page_content='✅ GitOps pipelines and Istio mesh configs'),
#  Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 5, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'ListItem', 'element_id': '86dac67156a49954c9afa742aa806570'}, page_content='✅ Agile runbooks and retrospectives')]

# %%
unstructured_docs[0]
# Out:
# Document(metadata={'source': 'data/doc_word/DevOps_Upskilling_Plan_Ayman.docx', 'category_depth': 0, 'emphasized_text_contents': ['🧭', 'DevOps Upskilling Plan'], 'emphasized_text_tags': ['b', 'b'], 'file_directory': 'data/doc_word', 'filename': 'DevOps_Upskilling_Plan_Ayman.docx', 'last_modified': '2025-07-29T21:13:59', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'UncategorizedText', 'element_id': '601609ac2b4ae7e7e15b4d0e0ff1555f'}, page_content='🧭 DevOps Upskilling Plan')
