# %% [markdown]
# ### LOAD PDF FILES

# %%
from langchain_community.document_loaders import(
    PyPDFLoader,
    UnstructuredPDFLoader,
    PyMuPDFLoader
)

# %%
### pyPDFLoader
print("PY PDF LOADER")
try:
    pdf_loader = PyPDFLoader("data/pdf/rapport.pdf")
    pdf_docs = pdf_loader.load()
    print(pdf_docs)
except Exception as e:
    print(f"PyPDFLoader failed: {e}")
# Out:
# PY PDF LOADER
# [Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-07-30T13:45:47-07:00', 'author': 'firdaous.charchaoui@etu.uae.ac.ma', 'moddate': '2025-07-30T13:45:47-07:00', 'source': 'data/pdf/rapport.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='1 \n \nRapport de Projet :  Prédiction des maladies \ncardiaques \nI. Introduction \n1. Contexte du Projet pour HealthCare Innovate \nLa détection précoce des maladies cardiovasculaires est un enjeu majeur pour l\'hôpital \nHealthCare Innovate. L\'afflux de patients et la complexité des profils cliniques rendent difficile \nla priorisation efficace de ceux qui bénéficieraient le plus d\'examens spécialisés.  \nCe projet a été initié pour déterminer si l\'intelligence artificielle peut fournir une assistance \nfiable aux équipes médicales en analysant les données patientes existantes pour estimer le \nrisque de maladie cardiaque. \n2. Objectifs Stratégiques \n• Appliquer un pipeline complet de science des données pour développer un modèle \nprédictif robuste. \n• Fournir aux médecins un outil objectif pour aider à la priorisation des patients. \n• Communiquer les résultats et le fonctionnement du modèle de manière claire et \naccessible à un public non expert. \n• Évaluer les implications éthiques et pratiques d\'un tel outil en contexte médical \nsensible. \nII. Méthodologie du Pipeline de Machine Learning \n1. Étape 1 : Exploration des Données (EDA) \nNous avons commencé par une analyse exploratoire approfondie du dataset "Heart Disease \nUCI". \n• Analyse des Variables : Le dataset contient des variables numériques (age, chol), \ncatégoriques (sex, cp) et une cible binaire (target), et aucune valeur manquante n\'a été \ndétectée dans la version fournie. \n• Analyse des Distributions : Les distributions des variables clés ont été visualisées \npour détecter des anomalies. Le dataset s\'est révélé relativement équilibré entre les \ncas positifs et négatifs. \n• Analyse des Corrélations : Une matrice de chaleur a révélé que les variables les plus \ncorrélées à la maladie cardiaque étaient le type de douleur thoracique (cp), la \ndépression du segment ST (oldpeak), la fréquence cardiaque maximale (thalach) et la \nprésence d\'une angine à l\'effort (exang).'), Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-07-30T13:45:47-07:00', 'author': 'firdaous.charchaoui@etu.uae.ac.ma', 'moddate': '2025-07-30T13:45:47-07:00', 'source': 'data/pdf/rapport.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content="2 \n \n \n2. Étape 2 : Nettoyage et Pipeline de Prétraitement \nPour assurer la cohérence et l'automatisation, un pipeline de prétraitement a été construit avec \nscikit-learn, qui effectue séquentiellement : \n• Imputation des valeurs manquantes (médiane pour le numérique, mode pour le \ncatégoriel). \n• Encodage des variables catégoriques en format numérique (OneHotEncoder). \n• Mise à l'échelle des variables numériques (StandardScaler) pour normaliser leur \nimpact sur le modèle. \n3. Étape 3 : Implémentation et Optimisation des Modèles \na. Sélection et Entraînement de Base : Trois modèles ont été comparés :  \nLogisticRegression, KNeighborsClassifier, et HistGradientBoostingClassifier. \nb. Optimisation : Les hyperparamètres de chaque modèle ont été optimisés via \nGridSearchCV.  \nLa métrique d'optimisation choisie était le F2-score, qui priorise fortement la \nminimisation des faux négatifs (le rappel) par rapport à la précision, ce qui est \ncrucial en médecine. \nc. Calibration : Le modèle final a été calibré avec CalibratedClassifierCV pour \ns'assurer que ses scores de probabilité sont fiables et peuvent être interprétés \ncomme un véritable pourcentage de risque. \nIII. Résultats et Évaluation des Performances \n1. Comparaison et Sélection du Modèle Final \nLe HistGradientBoostingClassifier (HGB) optimisé et calibré a offert le meilleur compromis \nentre performance et robust ...

# %%
# Method 2: PyMuPDFLoader (Fast and accurate)
print("\n📘 PyMuPDFLoader")
try:
    pymupdf_loader = PyMuPDFLoader("data/pdf/rapport.pdf")
    pymupdf_docs = pymupdf_loader.load()

    print(f"  Loaded {len(pymupdf_docs)} pages")
    print("  Includes detailed metadata")
    print(pymupdf_docs)
except Exception as e:
    print(f"  Error: {e}")
# Out:
# 📘 PyMuPDFLoader
#   Error: name 'PyMuPDFLoader' is not defined

# %% [markdown]
# 📄 PDF Loader Comparison:
#
# PyPDFLoader:
#   ✅ Simple and reliable
#   ✅ Good for most PDFs
#   ✅ Preserves page numbers
#   ❌ Basic text extraction
#   Use when: Standard text PDFs
#
# PyMuPDFLoader:
#   ✅ Fast processing
#   ✅ Good text extraction
#   ✅ Image extraction support
#   Use when: Speed is important

# %%
# Example of raw PDF extraction
raw_pdf_text = """Company Financial Report

The financial performance for fiscal year 2024
shows significant growth in profitability.

Revenue increased by 25%.

The company's efficiency improved due to workflow
optimization.

Page 1 of 10
"""

# Apply the cleaning function
def clean_text(text):
    # Remove excessive whitespace
    text = " ".join(text.split())

    # Fix ligatures
    text = text.replace("ﬁ", "fi")
    text = text.replace("ﬂ", "fl")

    return text


cleaned = clean_text(raw_pdf_text)
print("BEFORE:")
print(repr(raw_pdf_text[:100]))
print("\nAFTER:")
print(repr(cleaned[:100]))
# Out:
# BEFORE:
# 'Company Financial Report\n\nThe financial performance for fiscal year 2024\nshows significant growth in'
#
# AFTER:
# 'Company Financial Report The financial performance for fiscal year 2024 shows significant growth in '

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from langchain_core.documents import Document
from typing import List

class SmartPDFProcessor:
    """Advanced PDF processing with error handling"""

    def __init__(self, chunk_size=1000, chunk_overlap=100):
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            separators=[" "]
        )

    def process_pdf(self, pdf_path: str) -> List[Document]:
        """Process PDF with smart chunking and metadata enhancement"""

        # Load PDF
        loader = PyPDFLoader(pdf_path)
        pages = loader.load()

        ## Process each page
        processed_chunks = []

        for page_num, page in enumerate(pages):
            ## clean text
            cleaned_text = self._clean_text(page.page_content)

            # Skip nearly empty pages
            if len(cleaned_text.strip()) < 50:
                continue

            # Create chunks with enhanced metadata
            chunks = self.text_splitter.create_documents(
                texts=[cleaned_text],
                metadatas=[{
                    **page.metadata,
                    "page": page_num + 1,
                    "total_pages": len(pages),
                    "chunk_method": "smart_pdf_processor",
                    "char_count": len(cleaned_text)
                }]
            )
            processed_chunks.extend(chunks)
        return processed_chunks
    
    def _clean_text(self, text: str) -> str:
        """clean extracted text"""

        # Remove excessive whitespace
        text = " ".join(text.split())

        # Fix ligatures
        text = text.replace("ﬁ", "fi")
        text = text.replace("ﬂ", "fl")

        return text

# %%
preprocessor = SmartPDFProcessor()

# %%
## Process a PDF if available
try:
    smart_chunks = preprocessor.process_pdf("data/pdf/rapport.pdf")
    print(f"Processed into {len(smart_chunks)} smart chunks")

    # Show enhanced metadata
    if smart_chunks:
        print("\nSample chunk metadata:")
        for key, value in smart_chunks[0].metadata.items():
            print(f"  {key}: {value}")

except Exception as e:
    print(f"Processing error: {e}")
# Out:
# Processed into 10 smart chunks
#
# Sample chunk metadata:
#   producer: PyPDF
#   creator: Microsoft Word
#   creationdate: 2025-07-30T13:45:47-07:00
#   author: firdaous.charchaoui@etu.uae.ac.ma
#   moddate: 2025-07-30T13:45:47-07:00
#   source: data/pdf/rapport.pdf
#   total_pages: 5
#   page: 1
#   page_label: 1
#   chunk_method: smart_pdf_processor
#   char_count: 1911
